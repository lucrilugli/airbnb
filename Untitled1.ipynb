# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (1.35.0)
# Requirement already satisfied: altair<6,>=4.0 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: numpy<2,>=1.19.3 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<25,>=16.8 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from streamlit) (23.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from streamlit) (10.0.1)
# Requirement already satisfied: protobuf<5,>=3.20 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from streamlit) (4.7.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: jinja2 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2023.11.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: six>=1.5 in /Users/lucrezialugli/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)

# %%
# Imports

import streamlit as st
import pandas as pd
import pickle
import joblib

model = joblib.load('model.joblib')

data = {
    'm_interactions':[10],
    'contact_channel_first': [2],
    'total_reviews': [11.0],
    'guest_user_stage_first': [False]
}
df_test = pd.DataFrame(data)
y_pred = model.predict(df_test)
st.set_page_config(page_title = str(y_pred) 
                    ,page_icon = ":musical_note:" 
                    )



"""
# pandas options
pd.set_option('display.max_colwidth', None)

# setting the basic configuration of the web app. This is shown in the Tab
st.set_page_config(page_title = "#🎶Song Recommendations" 
                    ,page_icon = ":musical_note:" 
                    )

# read the data 
url = 'https://github.com/vkoul/data/raw/main/misc/spotify_data.zip'
df = pd.read_csv(url)

# add a column
df['song_url'] = 'https://open.spotify.com/track/' + df['id']


# Opening intro text
st.write("# 🎶Song Recommender✨")
st.write("#### Choose the parameters of the song:")

# Sliders for the values
# dance
dance_value = st.slider('Set the minimum level of dancebility?', min_value=0.0, max_value=1.0, value=0.2, step=0.1)

# acousticness
acoustic_value = st.slider('Set the minimum level of acousticness?', min_value=0.0, max_value=1.0, value=0.2, step=0.1)

# energy
energy_value = st.slider('Set the minimum level of energy?', min_value=0.0, max_value=1.0, value=0.2, step=0.1)

# instrumentalness
instrumental_value = st.slider('Set the minimum level of instrumentalness?', min_value=0.0, max_value=1.0, value=0.2, step=0.1)

# popularity
popularity_value = st.slider('Set the minimum level of popularity?', min_value=1.0, max_value=100.0, value=5.0, step=1.0)

# year
year_value = st.slider('Set the minimum level of year?', min_value=1921, max_value=2020, value=2019, step=1)

# filtering the data based on above criteria
df_filtered = df.query('danceability >= @dance_value & acousticness >= @acoustic_value & energy >= @energy_value &  instrumentalness >= @instrumental_value & popularity >= @popularity_value & year >= @year_value')

# Songs available in new 
total_unique_songs = df_filtered['name'].nunique()
st.write("Unique songs in the dataset mataching the above criteria: " + str(total_unique_songs))

# get the song list
song_name_list = df_filtered['name'].unique().tolist()

# Convert the names as a drop-down
option = st.selectbox(
    '**Which is your fav song?**',
    song_name_list)

st.write('**You selected:**', option)


# pass through the prediction
selection = df.query("name == @option ").select_dtypes(['int', 'float']).drop(columns = ['year', 'explicit', 'mode'])

#st.write(selection)

# load the scaler to scale the data 
scaler = pickle.load(open('scaler_pickle.sav','rb'))

# transform the data for for predictions
selection_scaled = scaler.transform(selection)

# st.write(selection_scaled)


# load the nearest neighbour model
nn_model = pickle.load(open('nn_model_prediction.sav','rb'))


# Generate the neigbors
neighbor_list = nn_model.kneighbors(selection_scaled,  return_distance=False)[:,1:].tolist()[0] # Skip the first value 

# st.write("The songs shorlisted are:", neighbor_list)


# Final list of predictions
neighbors = df.loc[neighbor_list,['name', 'song_url']]

# cleaning operations
neighbors = neighbors.reset_index(drop= True).rename(columns = {'name': 'Song', 'song_url': 'Spotify Link'})

# st.write(neighbors, unsafe_allow_html = True)

# use this to make table more clean https://github.com/softhints/Pandas-Tutorials/blob/master/styling/create-clickable-link-pandas-dataframe-jupyterlab.ipynb
# show the table
# st.dataframe(neighbors)
"""
# Out:
# '\n# pandas options\npd.set_option(\'display.max_colwidth\', None)\n\n# setting the basic configuration of the web app. This is shown in the Tab\nst.set_page_config(page_title = "#🎶Song Recommendations" \n                    ,page_icon = ":musical_note:" \n                    )\n\n# read the data \nurl = \'https://github.com/vkoul/data/raw/main/misc/spotify_data.zip\'\ndf = pd.read_csv(url)\n\n# add a column\ndf[\'song_url\'] = \'https://open.spotify.com/track/\' + df[\'id\']\n\n\n# Opening intro text\nst.write("# 🎶Song Recommender✨")\nst.write("#### Choose the parameters of the song:")\n\n# Sliders for the values\n# dance\ndance_value = st.slider(\'Set the minimum level of dancebility?\', min_value=0.0, max_value=1.0, value=0.2, step=0.1)\n\n# acousticness\nacoustic_value = st.slider(\'Set the minimum level of acousticness?\', min_value=0.0, max_value=1.0, value=0.2, step=0.1)\n\n# energy\nenergy_value = st.slider(\'Set the minimum level of energy?\', min_value=0.0, max_value=1.0, value=0.2, step=0.1)\n\n# instrumentalness\ninstrumental_value = st.slider(\'Set the minimum level of instrumentalness?\', min_value=0.0, max_value=1.0, value=0.2, step=0.1)\n\n# popularity\npopularity_value = st.slider(\'Set the minimum level of popularity?\', min_value=1.0, max_value=100.0, value=5.0, step=1.0)\n\n# year\nyear_value = st.slider(\'Set the minimum level of year?\', min_value=1921, max_value=2020, value=2019, step=1)\n\n# filtering the data based on above criteria\ndf_filtered = df.query(\'danceability >= @dance_value & acousticness >= @acoustic_value & energy >= @energy_value &  instrumentalness >= @instrumental_value & popularity >= @popularity_value & year >= @year_value\')\n\n# Songs available in new \ntotal_unique_songs = df_filtered[\'name\'].nunique()\nst.write("Unique songs in the dataset mataching the above criteria: " + str(total_unique_songs))\n\n# get the song list\nsong_name_list = df_filtered[\'name\'].unique().tolist()\n\n# Convert the names as a drop-down\noption = st.selectbox(\n    \'**Which is your fav song?**\',\n    song_name_list)\n\nst.write(\'**You selected:**\', option)\n\n\n# pass through the prediction\nselection = df.query("name == @option ").select_dtypes([\'int\', \'float\']).drop(columns = [\'year\', \'explicit\', \'mode\'])\n\n#st.write(selection)\n\n# load the scaler to scale the data \nscaler = pickle.load(open(\'scaler_pickle.sav\',\'rb\'))\n\n# transform the data for for predictions\nselection_scaled = scaler.transform(selection)\n\n# st.write(selection_scaled)\n\n\n# load the nearest neighbour model\nnn_model = pickle.load(open(\'nn_model_prediction.sav\',\'rb\'))\n\n\n# Generate the neigbors\nneighbor_list = nn_model.kneighbors(selection_scaled,  return_distance=False)[:,1:].tolist()[0] # Skip the first value \n\n# st.write("The songs shorlisted are:", neighbor_list)\n\n\n# Final list of predictions\nneighbors = df.loc[neighbor_list,[\'name\', \'song_url\']]\n\n# cleaning operations\nneighbors = neighbors.reset_index(drop= True).rename(columns = {\'name\': \'Song\', \'song_url\': \'Spotify Link\'})\n\n# st.write(neighbors, unsafe_allow_html = True)\n\n# use this to make table more clean https://github.com/softhints/Pandas-Tutorials/blob/master/styling/create-clickable-link-pandas-dataframe-jupyterlab.ipynb\n# show the table\n# st.dataframe(neighbors)\n'
